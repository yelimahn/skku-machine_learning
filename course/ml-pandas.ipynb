# %%
# reference 10 minutes to pandas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# object creation

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range('20130101', periods=6)
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.rand(6,4), index=dates, columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.238741  0.295422  0.920013  0.180665
# 2013-01-02  0.852979  0.503679  0.852249  0.036564
# 2013-01-03  0.787724  0.098458  0.839288  0.570094
# 2013-01-04  0.003828  0.596040  0.444137  0.037435
# 2013-01-05  0.582255  0.538101  0.748895  0.010366
# 2013-01-06  0.963921  0.287745  0.613413  0.646658

# %%
df2 = pd.DataFrame(
    {''}
)
