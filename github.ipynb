# %%
! git init
# Out:
# Initialized empty Git repository in /content/.git/

# %%
# !git config --global user.email amy2511@g.skku.edu
# !git config --global user.name yelimahn

# %%
! git add .

# %%
# !git commit -m "first commit"

# %%
# !git remote add origin https://github.com/yelimahn/skku-machine_learning.git

# %%
# !git remote rm origin

# %%
# !git push -u origin master
